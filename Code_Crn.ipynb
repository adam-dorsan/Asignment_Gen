# %%
point_1=0
point_2=0
point_3=0
total_point=0
count=0
age=input ("Are you a cigarette addict older than 75 years old?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
if age=="1":
    age=True
    point_1=int(point_1)
    point_1=9
elif age=="0":
    age=False
else:
    while age!="1" or age!="0":
        print ("",end="\n\n")
        print (" ----WRONG ENTRANCE---. Please re-enter")
        age=input ("Are you a cigarette addict older than 75 years old?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
        count+=1
        if age=="1" or age=="0" or count==3:
            count=0
            break
chronic = input ("Do you have a severe chronic disease ?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
if chronic=="1":
    chronic=True
    point_2=5
elif chronic=="0":
    chronic=False
else:
    while chronic!="1" or chronic!="0":
        print ("",end="\n\n")
        print (" ----WRONG ENTRANCE---. Please re-enter")
        chronic = input ("Do you have a severe chronic disease ?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
        count+=1
        if chronic=="1" or chronic=="0" or count==3:
            count=0
            break
immune = input ("Is your immune system too weak ?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
if immune=="1":
    immune=True
    point_3=3
elif immune=="0":
    immune=False
else:
    while immune!="1" or immune!="0":
        print ("",end="\n\n")
        print (" ----WRONG ENTRANCE---. Please re-enter")
        immune = input ("Is your immune system too weak ?__(For Answer -Yes- Press -1-  / For Answer -No- Press 0)")
        count+=1
        if immune=="1" or immune=="0" or count==3:
            count=0
            break
print ("",end="\n\n")
total_point=point_1+point_2+point_3
if age and chronic and immune:
    risk="Very High"
if age and 9 < total_point < 17:
    risk="High+"
if total_point==9:
    risk="High"
if total_point==8:
    risk="Moderate"
if 1 < total_point < 8:
    risk="Low"
if not age and not chronic and not immune:
    risk="You seem okey so far."
print ("Your risk to Corona virus {0}".format(risk))
